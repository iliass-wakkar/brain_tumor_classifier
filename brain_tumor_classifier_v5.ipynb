# %% [markdown]
# # 🧠 Brain Tumor Classification V5 - HIGH RESOLUTION
#
# **Key Changes from V4:**
# - **ResNet50V2** backbone (better gradient flow)
# - **299×299 resolution** (more detail for tumor detection)
# - **No label smoothing** (it hurt V4 performance)
# - **20 layers unfrozen** (back to V2's proven setting)
# - **1e-5 fine-tuning LR** (back to V2's proven setting)
# - **40 epochs Stage 2** with patience=10
#
# **Target: 85%+ accuracy**

# %% [markdown]
# ---
# ## Step 0: Set Working Directory

# %%
import os

TARGET_DIR = '/home/jovyan/work/cancer modele'

if os.path.exists(TARGET_DIR):
    os.chdir(TARGET_DIR)
    print(f"✅ Working directory: {os.getcwd()}")
else:
    print(f"⚠️ Directory not found: {TARGET_DIR}")
    print(f"   Current directory: {os.getcwd()}")

if os.path.exists('brain_tumor_dataset'):
    print("✅ Dataset found!")
else:
    print("❌ Dataset not found!")
# Out:
# ✅ Working directory: /home/jovyan/work/cancer modele
# ✅ Dataset found!

# %% [markdown]
# ---
# ## Step 1: Environment Setup & GPU Configuration

# %%
# !pip install -q "numpy<2.0" kaggle tensorflow pandas matplotlib seaborn scikit-learn

import os
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
import numpy as np

# Use single GPU with memory growth
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.set_visible_devices(gpus[0], 'GPU')
        tf.config.experimental.set_memory_growth(gpus[0], True)
        print(f"✅ Using GPU: {gpus[0].name}")
    except RuntimeError as e:
        print(f"⚠️ GPU config error: {e}")
else:
    print("⚠️ No GPU detected.")

print(f"📦 TensorFlow Version: {tf.__version__}")
# Out:
# 2025-12-21 21:21:09.363508: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-21 21:21:09.536489: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-21 21:21:09.573362: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-12-21 21:21:10.278272: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-12-21 21:21:10.278342: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-12-21 21:21:10.278350: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# ✅ Using GPU: /physical_device:GPU:0
# 📦 TensorFlow Version: 2.10.1

# %% [markdown]
# ---
# ## Step 2: Import Libraries

# %%
import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix

print("✅ All libraries imported successfully!")
# Out:
# ✅ All libraries imported successfully!

# %% [markdown]
# ---
# ## Step 3: Dataset Setup

# %%
os.environ['KAGGLE_CONFIG_DIR'] = os.getcwd()

TRAIN_DIR = 'brain_tumor_dataset/Training'
TEST_DIR = 'brain_tumor_dataset/Testing'

# Download if needed
if not os.path.exists('brain_tumor_dataset'):
    if os.path.exists('kaggle.json'):
        os.chmod('kaggle.json', 0o600)
        # !kaggle datasets download -d masoudnickparvar/brain-tumor-mri-dataset
        # !unzip -q brain-tumor-mri-dataset.zip -d brain_tumor_dataset
        print("✅ Dataset downloaded!")

# Verify dataset
print("\n📊 Dataset Distribution:")
for split, path in [('Training', TRAIN_DIR), ('Testing', TEST_DIR)]:
    print(f"\n{split}:")
    for class_name in sorted(os.listdir(path)):
        class_path = os.path.join(path, class_name)
        if os.path.isdir(class_path):
            print(f"  - {class_name}: {len(os.listdir(class_path))} images")
# Out:
# 📊 Dataset Distribution:
#
# Training:
#   - glioma: 1321 images
#   - meningioma: 1339 images
#   - notumor: 1595 images
#   - pituitary: 1457 images
#
# Testing:
#   - glioma: 300 images
#   - meningioma: 306 images
#   - notumor: 405 images
#   - pituitary: 300 images

# %% [markdown]
# ---
# ## Step 4: HIGH RESOLUTION Data Augmentation (299×299)
#
# **Key improvement:** Higher resolution captures more tumor detail!

# %%
# Configuration - HIGHER RESOLUTION!
IMG_SIZE = (299, 299)  # Increased from 224×224
BATCH_SIZE = 32
SEED = 42

# Medical-appropriate augmentation (proven in V2)
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1./255)

# Load Training Data (80%)
print("📥 Loading Training Data (80%)...")
train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training',
    seed=SEED,
    shuffle=True
)

# Load Validation Data (20%)
print("\n📥 Loading Validation Data (20%)...")
val_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation',
    seed=SEED,
    shuffle=False
)

# Load Test Data
print("\n📥 Loading Test Data...")
test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

CLASS_NAMES = list(train_generator.class_indices.keys())
NUM_CLASSES = len(CLASS_NAMES)

print(f"\n✅ Image Size: {IMG_SIZE}")
print(f"✅ Classes: {CLASS_NAMES}")
print(f"✅ Training samples: {train_generator.samples}")
print(f"✅ Validation samples: {val_generator.samples}")
print(f"✅ Test samples: {test_generator.samples}")
# Out:
# 📥 Loading Training Data (80%)...
# Found 4571 images belonging to 4 classes.
#
# 📥 Loading Validation Data (20%)...
# Found 1141 images belonging to 4 classes.
#
# 📥 Loading Test Data...
# Found 1311 images belonging to 4 classes.
#
# ✅ Image Size: (299, 299)
# ✅ Classes: ['glioma', 'meningioma', 'notumor', 'pituitary']
# ✅ Training samples: 4571
# ✅ Validation samples: 1141
# ✅ Test samples: 1311

# %% [markdown]
# ---
# ## Step 5: Build ResNet50V2 Model
#
# **ResNet50V2** has improved residual connections with better gradient flow.

# %%
def build_model(num_classes=4, freeze_backbone=True):
    """
    Build ResNet50V2 with simple classification head.
    V2 = improved pre-activation residual blocks.
    """
    # Load pretrained ResNet50V2
    base_model = ResNet50V2(
        weights='imagenet',
        include_top=False,
        input_shape=(299, 299, 3)
    )
    
    # Freeze backbone initially
    base_model.trainable = not freeze_backbone
    
    # Simple classification head (proven to work in V2)
    x = base_model.output
    x = GlobalAveragePooling2D(name='avg_pool')(x)
    x = Dropout(0.5, name='dropout_1')(x)
    x = Dense(256, activation='relu', name='fc1')(x)
    x = Dropout(0.3, name='dropout_2')(x)
    predictions = Dense(num_classes, activation='softmax', name='predictions')(x)
    
    model = Model(inputs=base_model.input, outputs=predictions)
    
    return model, base_model

# Build model with frozen backbone
model, base_model = build_model(num_classes=NUM_CLASSES, freeze_backbone=True)

# Count parameters
total_params = model.count_params()
trainable_params = sum([tf.keras.backend.count_params(w) for w in model.trainable_weights])
non_trainable_params = total_params - trainable_params

print("🏗️ Model Architecture Summary:")
print(f"   Backbone: ResNet50V2")
print(f"   Input Size: 299×299×3")
print(f"   Total Parameters: {total_params:,}")
print(f"   Trainable Parameters: {trainable_params:,}")
print(f"   Non-trainable Parameters: {non_trainable_params:,}")
print(f"   Backbone Layers: {len(base_model.layers)}")
# Out:
# 2025-12-21 21:21:12.957346: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-21 21:21:13.619094: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 41350 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:4b:00.0, compute capability: 8.6
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 3s 0us/step
# 🏗️ Model Architecture Summary:
#    Backbone: ResNet50V2
#    Input Size: 299×299×3
#    Total Parameters: 24,090,372
#    Trainable Parameters: 525,572
#    Non-trainable Parameters: 23,564,800
#    Backbone Layers: 190

# %% [markdown]
# ---
# ## Step 6: Define Callbacks

# %%
# Callbacks for Stage 1
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True,
    verbose=1
)

checkpoint = ModelCheckpoint(
    'best_brain_tumor_model_v5.keras',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-7,
    verbose=1
)

print("✅ Callbacks configured")
# Out:
# ✅ Callbacks configured

# %% [markdown]
# ---
# ## Step 7: Stage 1 — Warm-up Training (Frozen Backbone) ❄️

# %%
print("🚀 STAGE 1: Training Custom Head (Backbone Frozen)")
print("=" * 50)

# Ensure backbone is frozen
base_model.trainable = False

# Compile WITHOUT label smoothing (it hurt V4)
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',  # NO label smoothing!
    metrics=['accuracy']
)

EPOCHS_STAGE1 = 10

history_stage1 = model.fit(
    train_generator,
    epochs=EPOCHS_STAGE1,
    validation_data=val_generator,
    callbacks=[early_stop, checkpoint, reduce_lr],
    verbose=1
)

print(f"\n✅ Stage 1 Complete!")
print(f"   Best Val Accuracy: {max(history_stage1.history['val_accuracy']):.4f}")
# Out:
# 🚀 STAGE 1: Training Custom Head (Backbone Frozen)
# ==================================================
# Epoch 1/10
# 2025-12-21 21:21:22.484323: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8900
#   2/143 [..............................] - ETA: 7s - loss: 1.9180 - accuracy: 0.2969
# 2025-12-21 21:21:23.742469: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 143/143 [==============================] - ETA: 0s - loss: 1.0342 - accuracy: 0.5767
# Epoch 1: val_accuracy improved from -inf to 0.71253, saving model to best_brain_tumor_model_v5.keras
# 143/143 [==============================] - 97s 648ms/step - loss: 1.0342 - accuracy: 0.5767 - val_loss: 0.8698 - val_accuracy: 0.7125 - lr: 1.0000e-04
# Epoch 2/10
# 143/143 [==============================] - ETA: 0s - loss: 0.6223 - accuracy: 0.7613
# Epoch 2: val_accuracy improved from 0.71253 to 0.72656, saving model to best_brain_tumor_model_v5.keras
# 143/143 [==============================] - 91s 635ms/step - loss: 0.6223 - accuracy: 0.7613 - val_loss: 0.7948 - val_accuracy: 0.7266 - lr: 1.0000e-04
# Epoch 3/10
# 143/143 [==============================] - ETA: 0s - loss: 0.5161 - accuracy: 0.8031
# Epoch 3: val_accuracy improved from 0.72656 to 0.75022, saving model to best_brain_tumor_model_v5.keras
# 143/143 [==============================] - 91s 636ms/step - loss: 0.5161 - accuracy: 0.8031 - val_loss: 0.7339 - val_accuracy: 0.7502 - lr: 1.0000e-04
# Epoch 4/10
# 143/143 [==============================] - ETA: 0s - loss: 0.4803 - accuracy: 0.8243
# Epoch 4: val_accuracy improved from 0.75022 to 0.77038, saving model to best_brain_tumor_model_v5.keras
# 143/143 [==============================] - 92s 644ms/step - loss: 0.4803 - accuracy: 0.8243 - val_loss: 0.6562 - val_accuracy: 0.7704 - lr: 1.0000e-04
# Epoch 5/10
# 143/143 [==============================] - ETA: 0s - loss: 0.4209 - accuracy: 0.8451
# Epoch 5: val_accuracy did not improve from 0.77038
# 143/143 [==============================] - 91s 636ms/step - loss: 0.4209 - accuracy: 0.8451 - val_loss: 0.6182 - val_accuracy: 0.7651 - lr: 1.0000e-04
# Epoch 6/10
# 143/143 [==============================] - ETA: 0s - loss: 0.4221 - accuracy: 0.8403
# Epoch 6: val_accuracy improved from 0.77038 to 0.79404, saving model to best_brain_tumor_model_v5.keras
# 143/143 [==============================] - 92s 643ms/step - loss: 0.4221 - accuracy: 0.8403 - val_loss: 0.5738 - val_accuracy: 0.7940 - lr: 1.0000e-04
# Epoch 7/10
# 143/143 [==============================] - ETA: 0s - loss: 0.4042 - accuracy: 0.8512
# Epoch 7: val_accuracy did not improve from 0.79404
# 143/143 [==============================] - 90s 633ms/step - loss: 0.4042 - accuracy: 0.8512 - val_loss: 0.5260 - val_accuracy: 0.7940 - lr: 1.0000e-04
# Epoch 8/10
# 143/143 [==============================] - ETA: 0s - loss: 0.3745 - accuracy: 0.8630
# Epoch 8: val_accuracy improved from 0.79404 to 0.81069, saving model to best_brain_tumor_model_v5.keras
# 143/143 [==============================] - 93s 649ms/step - loss: 0.3745 - accuracy: 0.8630 - val_loss: 0.5172 - val_accuracy: 0.8107 - lr: 1.0000e-04
# Epoch 9/10
# 143/143 [==============================] - ETA: 0s - loss: 0.3683 - accuracy: 0.8635
# Epoch 9: val_accuracy did not improve from 0.81069
# 143/143 [==============================] - 90s 632ms/step - loss: 0.3683 - accuracy: 0.8635 - val_loss: 0.5470 - val_accuracy: 0.7897 - lr: 1.0000e-04
# Epoch 10/10
# 143/143 [==============================] - ETA: 0s - loss: 0.3600 - accuracy: 0.8665
# Epoch 10: val_accuracy did not improve from 0.81069
# 143/143 [==============================] - 91s 638ms/step - loss: 0.3600 - accuracy: 0.8665 - val_loss: 0.5797 - val_accuracy: 0.7940 - lr: 1.0000e-04
#
# ✅ Stage 1 Complete!
#    Best Val Accuracy: 0.8107

# %% [markdown]
# ---
# ## Step 8: Stage 2 — Fine-tuning (Unfreeze Top 20 Layers) 🔥
#
# Back to V2's proven settings: 20 layers, 1e-5 learning rate.

# %%
print("🔥 STAGE 2: Fine-tuning (Unfreezing Top 20 Layers)")
print("=" * 50)

# Unfreeze last 20 layers (like V2)
base_model.trainable = True
FREEZE_UNTIL = len(base_model.layers) - 20
for layer in base_model.layers[:FREEZE_UNTIL]:
    layer.trainable = False

trainable_count = sum([tf.keras.backend.count_params(w) for w in model.trainable_weights])
print(f"\n📊 Trainable parameters after unfreezing: {trainable_count:,}")

# Re-compile with V2's learning rate (1e-5)
model.compile(
    optimizer=Adam(learning_rate=1e-5),  # V2's proven LR
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Stage 2 callbacks with more patience
early_stop_stage2 = EarlyStopping(
    monitor='val_loss',
    patience=10,  # More patience
    restore_best_weights=True,
    verbose=1
)

checkpoint_stage2 = ModelCheckpoint(
    'best_brain_tumor_model_v5_finetuned.keras',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

reduce_lr_stage2 = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-7,
    verbose=1
)

EPOCHS_STAGE2 = 40  # More epochs

history_stage2 = model.fit(
    train_generator,
    epochs=EPOCHS_STAGE2,
    validation_data=val_generator,
    callbacks=[early_stop_stage2, checkpoint_stage2, reduce_lr_stage2],
    verbose=1
)

print(f"\n✅ Stage 2 Complete!")
print(f"   Best Val Accuracy: {max(history_stage2.history['val_accuracy']):.4f}")
# Out:
# 🔥 STAGE 2: Fine-tuning (Unfreezing Top 20 Layers)
# ==================================================
#
# 📊 Trainable parameters after unfreezing: 8,405,252
# Epoch 1/40
# 143/143 [==============================] - ETA: 0s - loss: 0.3518 - accuracy: 0.8744
# Epoch 1: val_accuracy improved from -inf to 0.80631, saving model to best_brain_tumor_model_v5_finetuned.keras
# 143/143 [==============================] - 94s 635ms/step - loss: 0.3518 - accuracy: 0.8744 - val_loss: 0.4961 - val_accuracy: 0.8063 - lr: 1.0000e-05
# Epoch 2/40
# 143/143 [==============================] - ETA: 0s - loss: 0.2646 - accuracy: 0.9020
# Epoch 2: val_accuracy improved from 0.80631 to 0.84312, saving model to best_brain_tumor_model_v5_finetuned.keras
# 143/143 [==============================] - 91s 638ms/step - loss: 0.2646 - accuracy: 0.9020 - val_loss: 0.4083 - val_accuracy: 0.8431 - lr: 1.0000e-05
# Epoch 3/40
# 143/143 [==============================] - ETA: 0s - loss: 0.2350 - accuracy: 0.9158
# Epoch 3: val_accuracy improved from 0.84312 to 0.85276, saving model to best_brain_tumor_model_v5_finetuned.keras
# 143/143 [==============================] - 92s 642ms/step - loss: 0.2350 - accuracy: 0.9158 - val_loss: 0.3685 - val_accuracy: 0.8528 - lr: 1.0000e-05
# Epoch 4/40
# 143/143 [==============================] - ETA: 0s - loss: 0.2092 - accuracy: 0.9201
# Epoch 4: val_accuracy improved from 0.85276 to 0.87730, saving model to best_brain_tumor_model_v5_finetuned.keras
# 143/143 [==============================] - 90s 632ms/step - loss: 0.2092 - accuracy: 0.9201 - val_loss: 0.3256 - val_accuracy: 0.8773 - lr: 1.0000e-05
# Epoch 5/40
# 143/143 [==============================] - ETA: 0s - loss: 0.1796 - accuracy: 0.9381
# Epoch 5: val_accuracy improved from 0.87730 to 0.89658, saving model to best_brain_tumor_model_v5_finetuned.keras
# 143/143 [==============================] - 91s 640ms/step - loss: 0.1796 - accuracy: 0.9381 - val_loss: 0.3163 - val_accuracy: 0.8966 - lr: 1.0000e-05
# Epoch 6/40
# 143/143 [==============================] - ETA: 0s - loss: 0.1621 - accuracy: 0.9414
# Epoch 6: val_accuracy improved from 0.89658 to 0.89921, saving model to best_brain_tumor_model_v5_finetuned.keras
# 143/143 [==============================] - 90s 633ms/step - loss: 0.1621 - accuracy: 0.9414 - val_loss: 0.2810 - val_accuracy: 0.8992 - lr: 1.0000e-05
# Epoch 7/40
# 143/143 [==============================] - ETA: 0s - loss: 0.1539 - accuracy: 0.9418
# Epoch 7: val_accuracy did not improve from 0.89921
# 143/143 [==============================] - 91s 639ms/step - loss: 0.1539 - accuracy: 0.9418 - val_loss: 0.2889 - val_accuracy: 0.8931 - lr: 1.0000e-05
# Epoch 8/40
# 143/143 [==============================] - ETA: 0s - loss: 0.1213 - accuracy: 0.9589
# Epoch 8: val_accuracy improved from 0.89921 to 0.91411, saving model to best_brain_tumor_model_v5_finetuned.keras
# 143/143 [==============================] - 92s 641ms/step - loss: 0.1213 - accuracy: 0.9589 - val_loss: 0.2445 - val_accuracy: 0.9141 - lr: 1.0000e-05
# Epoch 9/40
# 143/143 [==============================] - ETA: 0s - loss: 0.1314 - accuracy: 0.9499
# Epoch 9: val_accuracy improved from 0.91411 to 0.91762, saving model to best_brain_tumor_model_v5_finetuned.keras
# 143/143 [==============================] - 92s 643ms/step - loss: 0.1314 - accuracy: 0.9499 - val_loss: 0.2412 - val_accuracy: 0.9176 - lr: 1.0000e-05
# Epoch 10/40
# 143/143 [==============================] - ETA: 0s - loss: 0.1093 - accuracy: 0.9635
# Epoch 10: val_accuracy improved from 0.91762 to 0.91937, saving model to best_brain_tumor_model_v5_finetuned.keras
# 143/143 [==============================] - 91s 640ms/step - loss: 0.1093 - accuracy: 0.9635 - val_loss: 0.2376 - val_accuracy: 0.9194 - lr: 1.0000e-05
# Epoch 11/40
# 143/143 [==============================] - ETA: 0s - loss: 0.0997 - accuracy: 0.9637
# Epoch 11: val_accuracy improved from 0.91937 to 0.93690, saving model to best_brain_tumor_model_v5_finetuned.keras
# 143/143 [==============================] - 92s 644ms/step - loss: 0.0997 - accuracy: 0.9637 - val_loss: 0.2105 - val_accuracy: 0.9369 - lr: 1.0000e-05
# Epoch 12/40
# 143/143 [==============================] - ETA: 0s - loss: 0.0823 - accuracy: 0.9702
# Epoch 12: val_accuracy did not improve from 0.93690
# 143/143 [==============================] - 91s 638ms/step - loss: 0.0823 - accuracy: 0.9702 - val_loss: 0.2341 - val_accuracy: 0.9264 - lr: 1.0000e-05
# Epoch 13/40
# 143/143 [==============================] - ETA: 0s - loss: 0.0758 - accuracy: 0.9751
# Epoch 13: val_accuracy did not improve from 0.93690
# 143/143 [==============================] - 91s 634ms/step - loss: 0.0758 - accuracy: 0.9751 - val_loss: 0.2469 - val_accuracy: 0.9264 - lr: 1.0000e-05
# Epoch 14/40
# 143/143 [==============================] - ETA: 0s - loss: 0.0803 - accuracy: 0.9727
# Epoch 14: val_accuracy did not improve from 0.93690
# 143/143 [==============================] - 90s 630ms/step - loss: 0.0803 - accuracy: 0.9727 - val_loss: 0.2036 - val_accuracy: 0.9351 - lr: 1.0000e-05
# Epoch 15/40
# 143/143 [==============================] - ETA: 0s - loss: 0.0740 - accuracy: 0.9733
# Epoch 15: val_accuracy did not improve from 0.93690
# 143/143 [==============================] - 90s 630ms/step - loss: 0.0740 - accuracy: 0.9733 - val_loss: 0.2206 - val_accuracy: 0.9325 - lr: 1.0000e-05
# Epoch 16/40
# 143/143 [==============================] - ETA: 0s - loss: 0.0640 - accuracy: 0.9786
# Epoch 16: val_accuracy did not improve from 0.93690
# 143/143 [==============================] - 89s 624ms/step - loss: 0.0640 - accuracy: 0.9786 - val_loss: 0.2042 - val_accuracy: 0.9316 - lr: 1.0000e-05
# Epoch 17/40
# 143/143 [==============================] - ETA: 0s - loss: 0.0609 - accuracy: 0.9814
# Epoch 17: val_accuracy did not improve from 0.93690
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 143/143 [==============================] - 90s 631ms/step - loss: 0.0609 - accuracy: 0.9814 - val_loss: 0.2070 - val_accuracy: 0.9325 - lr: 1.0000e-05
# Epoch 18/40
# 143/143 [==============================] - ETA: 0s - loss: 0.0615 - accuracy: 0.9797
# Epoch 18: val_accuracy improved from 0.93690 to 0.93865, saving model to best_brain_tumor_model_v5_finetuned.keras
# 143/143 [==============================] - 92s 643ms/step - loss: 0.0615 - accuracy: 0.9797 - val_loss: 0.2152 - val_accuracy: 0.9387 - lr: 5.0000e-06
# Epoch 19/40
# 143/143 [==============================] - ETA: 0s - loss: 0.0581 - accuracy: 0.9779
# Epoch 19: val_accuracy did not improve from 0.93865
# 143/143 [==============================] - 91s 633ms/step - loss: 0.0581 - accuracy: 0.9779 - val_loss: 0.2054 - val_accuracy: 0.9334 - lr: 5.0000e-06
# Epoch 20/40
# 143/143 [==============================] - ETA: 0s - loss: 0.0469 - accuracy: 0.9869
# Epoch 20: val_accuracy did not improve from 0.93865
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 143/143 [==============================] - 91s 635ms/step - loss: 0.0469 - accuracy: 0.9869 - val_loss: 0.2134 - val_accuracy: 0.9378 - lr: 5.0000e-06
# Epoch 21/40
# 143/143 [==============================] - ETA: 0s - loss: 0.0576 - accuracy: 0.9779
# Epoch 21: val_accuracy improved from 0.93865 to 0.94741, saving model to best_brain_tumor_model_v5_finetuned.keras
# 143/143 [==============================] - 90s 632ms/step - loss: 0.0576 - accuracy: 0.9779 - val_loss: 0.1837 - val_accuracy: 0.9474 - lr: 2.5000e-06
# Epoch 22/40
# 143/143 [==============================] - ETA: 0s - loss: 0.0472 - accuracy: 0.9862
# Epoch 22: val_accuracy did not improve from 0.94741
# 143/143 [==============================] - 89s 623ms/step - loss: 0.0472 - accuracy: 0.9862 - val_loss: 0.1940 - val_accuracy: 0.9430 - lr: 2.5000e-06
# Epoch 23/40
# 143/143 [==============================] - ETA: 0s - loss: 0.0525 - accuracy: 0.9823
# Epoch 23: val_accuracy did not improve from 0.94741
# 143/143 [==============================] - 90s 632ms/step - loss: 0.0525 - accuracy: 0.9823 - val_loss: 0.2030 - val_accuracy: 0.9360 - lr: 2.5000e-06
# Epoch 24/40
# 143/143 [==============================] - ETA: 0s - loss: 0.0418 - accuracy: 0.9845
# Epoch 24: val_accuracy improved from 0.94741 to 0.94829, saving model to best_brain_tumor_model_v5_finetuned.keras
# 143/143 [==============================] - 93s 651ms/step - loss: 0.0418 - accuracy: 0.9845 - val_loss: 0.1828 - val_accuracy: 0.9483 - lr: 2.5000e-06
# Epoch 25/40
# 143/143 [==============================] - ETA: 0s - loss: 0.0483 - accuracy: 0.9851
# Epoch 25: val_accuracy improved from 0.94829 to 0.94917, saving model to best_brain_tumor_model_v5_finetuned.keras
# 143/143 [==============================] - 92s 641ms/step - loss: 0.0483 - accuracy: 0.9851 - val_loss: 0.1844 - val_accuracy: 0.9492 - lr: 2.5000e-06
# Epoch 26/40
# 143/143 [==============================] - ETA: 0s - loss: 0.0401 - accuracy: 0.9862
# Epoch 26: val_accuracy did not improve from 0.94917
# 143/143 [==============================] - 90s 632ms/step - loss: 0.0401 - accuracy: 0.9862 - val_loss: 0.1747 - val_accuracy: 0.9430 - lr: 2.5000e-06
# Epoch 27/40
# 143/143 [==============================] - ETA: 0s - loss: 0.0465 - accuracy: 0.9834
# Epoch 27: val_accuracy did not improve from 0.94917
# 143/143 [==============================] - 92s 642ms/step - loss: 0.0465 - accuracy: 0.9834 - val_loss: 0.1807 - val_accuracy: 0.9448 - lr: 2.5000e-06
# Epoch 28/40
# 143/143 [==============================] - ETA: 0s - loss: 0.0403 - accuracy: 0.9873
# Epoch 28: val_accuracy did not improve from 0.94917
# 143/143 [==============================] - 91s 635ms/step - loss: 0.0403 - accuracy: 0.9873 - val_loss: 0.1950 - val_accuracy: 0.9395 - lr: 2.5000e-06
# Epoch 29/40
# 143/143 [==============================] - ETA: 0s - loss: 0.0454 - accuracy: 0.9864
# Epoch 29: val_accuracy did not improve from 0.94917
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 143/143 [==============================] - 90s 633ms/step - loss: 0.0454 - accuracy: 0.9864 - val_loss: 0.1947 - val_accuracy: 0.9422 - lr: 2.5000e-06
# Epoch 30/40
# 143/143 [==============================] - ETA: 0s - loss: 0.0385 - accuracy: 0.9882
# Epoch 30: val_accuracy did not improve from 0.94917
# 143/143 [==============================] - 89s 623ms/step - loss: 0.0385 - accuracy: 0.9882 - val_loss: 0.1949 - val_accuracy: 0.9413 - lr: 1.2500e-06
# Epoch 31/40
# 143/143 [==============================] - ETA: 0s - loss: 0.0381 - accuracy: 0.9867
# Epoch 31: val_accuracy did not improve from 0.94917
# 143/143 [==============================] - 91s 634ms/step - loss: 0.0381 - accuracy: 0.9867 - val_loss: 0.1855 - val_accuracy: 0.9430 - lr: 1.2500e-06
# Epoch 32/40
# 143/143 [==============================] - ETA: 0s - loss: 0.0393 - accuracy: 0.9869
# Epoch 32: val_accuracy did not improve from 0.94917
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-07.
# 143/143 [==============================] - 89s 621ms/step - loss: 0.0393 - accuracy: 0.9869 - val_loss: 0.1995 - val_accuracy: 0.9360 - lr: 1.2500e-06
# Epoch 33/40
# 143/143 [==============================] - ETA: 0s - loss: 0.0405 - accuracy: 0.9867
# Epoch 33: val_accuracy improved from 0.94917 to 0.95004, saving model to best_brain_tumor_model_v5_finetuned.keras
# 143/143 [==============================] - 91s 634ms/step - loss: 0.0405 - accuracy: 0.9867 - val_loss: 0.1882 - val_accuracy: 0.9500 - lr: 6.2500e-07
# Epoch 34/40
# 143/143 [==============================] - ETA: 0s - loss: 0.0346 - accuracy: 0.9888
# Epoch 34: val_accuracy did not improve from 0.95004
# 143/143 [==============================] - 90s 628ms/step - loss: 0.0346 - accuracy: 0.9888 - val_loss: 0.1795 - val_accuracy: 0.9492 - lr: 6.2500e-07
# Epoch 35/40
# 143/143 [==============================] - ETA: 0s - loss: 0.0345 - accuracy: 0.9880
# Epoch 35: val_accuracy did not improve from 0.95004
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-07.
# 143/143 [==============================] - 90s 627ms/step - loss: 0.0345 - accuracy: 0.9880 - val_loss: 0.1862 - val_accuracy: 0.9448 - lr: 6.2500e-07
# Epoch 36/40
# 143/143 [==============================] - ETA: 0s - loss: 0.0330 - accuracy: 0.9884Restoring model weights from the end of the best epoch: 26.
#
# Epoch 36: val_accuracy did not improve from 0.95004
# 143/143 [==============================] - 91s 636ms/step - loss: 0.0330 - accuracy: 0.9884 - val_loss: 0.1994 - val_accuracy: 0.9422 - lr: 3.1250e-07
# Epoch 36: early stopping
#
# ✅ Stage 2 Complete!
#    Best Val Accuracy: 0.9500

# %% [markdown]
# ---
# ## Step 9: Training History Visualization

# %%
def plot_training_history(history1, history2):
    """Plot combined training history from both stages."""
    
    # Combine histories
    acc = history1.history['accuracy'] + history2.history['accuracy']
    val_acc = history1.history['val_accuracy'] + history2.history['val_accuracy']
    loss = history1.history['loss'] + history2.history['loss']
    val_loss = history1.history['val_loss'] + history2.history['val_loss']
    
    epochs = range(1, len(acc) + 1)
    stage1_end = len(history1.history['accuracy'])
    
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    
    # Accuracy plot
    axes[0].plot(epochs, acc, 'b-', label='Training Accuracy', linewidth=2)
    axes[0].plot(epochs, val_acc, 'r-', label='Validation Accuracy', linewidth=2)
    axes[0].axvline(x=stage1_end, color='green', linestyle='--', label='Fine-tuning Start')
    axes[0].set_title('Model Accuracy (V5 - ResNet50V2 299×299)', fontsize=14, fontweight='bold')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Accuracy')
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)
    
    # Loss plot
    axes[1].plot(epochs, loss, 'b-', label='Training Loss', linewidth=2)
    axes[1].plot(epochs, val_loss, 'r-', label='Validation Loss', linewidth=2)
    axes[1].axvline(x=stage1_end, color='green', linestyle='--', label='Fine-tuning Start')
    axes[1].set_title('Model Loss (V5 - ResNet50V2 299×299)', fontsize=14, fontweight='bold')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig('training_history_v5.png', dpi=150)
    plt.show()
    print("\n📊 Training history saved to 'training_history_v5.png'")

plot_training_history(history_stage1, history_stage2)
# Out:
# 📊 Training history saved to 'training_history_v5.png'

# %% [markdown]
# ---
# ## Step 10: Model Evaluation on Test Set

# %%
print("📊 EVALUATING MODEL ON TEST SET")
print("=" * 50)

# Load best model
from tensorflow.keras.models import load_model

best_model_path = 'best_brain_tumor_model_v5_finetuned.keras'
if os.path.exists(best_model_path):
    model = load_model(best_model_path)
    print(f"✅ Loaded best model from: {best_model_path}")

# Evaluate on test set
test_loss, test_accuracy = model.evaluate(test_generator, verbose=0)
print(f"\n🎯 Test Loss: {test_loss:.4f}")
print(f"🎯 Test Accuracy: {test_accuracy:.4f} ({test_accuracy*100:.2f}%)")

# Generate predictions
print("\n⏳ Generating predictions...")
test_generator.reset()
predictions = model.predict(test_generator, verbose=1)
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# Classification Report
print("\n" + "=" * 50)
print("📋 CLASSIFICATION REPORT")
print("=" * 50)
print(classification_report(y_true, y_pred, target_names=CLASS_NAMES, digits=4))
# Out:
# 📊 EVALUATING MODEL ON TEST SET
# ==================================================
# ✅ Loaded best model from: best_brain_tumor_model_v5_finetuned.keras
#
# 🎯 Test Loss: 0.1351
# 🎯 Test Accuracy: 0.9596 (95.96%)
#
# ⏳ Generating predictions...
# 41/41 [==============================] - 5s 110ms/step
#
# ==================================================
# 📋 CLASSIFICATION REPORT
# ==================================================
#               precision    recall  f1-score   support
#
#       glioma     0.9589    0.9333    0.9459       300
#   meningioma     0.9307    0.9216    0.9261       306
#      notumor     0.9851    0.9827    0.9839       405
#    pituitary     0.9551    0.9933    0.9739       300
#
#     accuracy                         0.9596      1311
#    macro avg     0.9575    0.9577    0.9575      1311
# weighted avg     0.9596    0.9596    0.9594      1311

# %% [markdown]
# ---
# ## Step 11: Confusion Matrix Visualization

# %%
print("\n📊 CONFUSION MATRIX")
print("=" * 50)

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plot
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Raw counts
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES, ax=axes[0])
axes[0].set_title('Confusion Matrix (Counts)', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('Actual')

# Normalized (percentages)
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
sns.heatmap(cm_norm, annot=True, fmt='.2%', cmap='Blues',
            xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES, ax=axes[1])
axes[1].set_title('Confusion Matrix (Normalized)', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Predicted')
axes[1].set_ylabel('Actual')

plt.tight_layout()
plt.savefig('confusion_matrix_v5.png', dpi=150)
plt.show()
print("\n📊 Confusion matrix saved to 'confusion_matrix_v5.png'")
# Out:
# 📊 CONFUSION MATRIX
# ==================================================
# 📊 Confusion matrix saved to 'confusion_matrix_v5.png'

# %% [markdown]
# ---
# ## Step 12: Per-Class Performance Analysis

# %%
print("\n📊 PER-CLASS PERFORMANCE ANALYSIS")
print("=" * 50)

# Calculate per-class accuracy
for i, class_name in enumerate(CLASS_NAMES):
    class_mask = (y_true == i)
    class_correct = (y_pred[class_mask] == i).sum()
    class_total = class_mask.sum()
    class_acc = class_correct / class_total
    print(f"   {class_name}: {class_acc:.2%} ({class_correct}/{class_total})")

print("\n" + "=" * 50)
print("✅ V5 TRAINING COMPLETE!")
print("=" * 50)
# Out:
# 📊 PER-CLASS PERFORMANCE ANALYSIS
# ==================================================
#    glioma: 93.33% (280/300)
#    meningioma: 92.16% (282/306)
#    notumor: 98.27% (398/405)
#    pituitary: 99.33% (298/300)
#
# ==================================================
# ✅ V5 TRAINING COMPLETE!
# ==================================================

# %% [markdown]
# ---
# ## Summary: V5 Configuration
#
# | Parameter | V2 (78%) | V4 (71%) | V5 |
# |-----------|----------|----------|----|
# | **Backbone** | ResNet50 | ResNet50 | **ResNet50V2** |
# | **Image Size** | 224×224 | 224×224 | **299×299** |
# | **Label Smoothing** | No | Yes (0.1) | **No** |
# | **Layers Unfrozen** | 20 | 15 | **20** |
# | **Fine-tune LR** | 1e-5 | 5e-6 | **1e-5** |
# | **Stage 2 Epochs** | 20 | 25 | **40** |
# | **Early Stop Patience** | 5 | 8 | **10** |
